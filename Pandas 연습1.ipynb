# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\byeol\Desktop\머신 러닝\test2\Independence100.csv')
df.head(2)
# Out:
#    Rank                Restaurant       Sales  Average Check      City State  \
# 0     1  Carmine's (Times Square)  39080335.0             40  New York  N.Y.
# 1     2     The Boathouse Orlando  35218364.0             43  Orlando   Fla.
#
#    Meals Served
# 0      469803.0
# 1      820819.0

# %%
df.rename({'Restaurant':'식당','Sales':'판매액','Average Check':'평균','Meals Served':'서빙수'}, axis=1, inplace=True)
df.rename({'City' : '도시','State':'주','Rank':'랭크'},axis=1,inplace=True)

# %%
df
# Out:
#     Rank                                   식당         판매액  평균        City  \
# 0      1             Carmine's (Times Square)  39080335.0  40    New York
# 1      2                The Boathouse Orlando  35218364.0  43    Orlando
# 2      3                     Old Ebbitt Grill  29104017.0  33  Washington
# 3      4  LAVO Italian Restaurant & Nightclub  26916180.0  90    New York
# 4      5             Bryant Park Grill & Cafe  26900000.0  62    New York
# ..   ...                                  ...         ...  ..         ...
# 95    96                 George's at the Cove  12194000.0  80    La Jolla
# 96    97                            Le Coucou  12187523.0  95    New York
# 97    98                              Mi Vida  12032014.0  38  Washington
# 98    99                               Upland  11965564.0  52    New York
# 99   100               Virgil's Real Barbecue  11391678.0  27   Las Vegas
#
#      State       서빙수
# 0     N.Y.  469803.0
# 1     Fla.  820819.0
# ...

# %%
cond1 = (df['판매액']>=12000000)
cond2 = (df['City'] == 'New York')
df.loc[cond1 & cond2]
# Out:
#     Rank                                           식당         판매액   평균  \
# 0      1                     Carmine's (Times Square)  39080335.0   40
# 3      4          LAVO Italian Restaurant & Nightclub  26916180.0   90
# 4      5                     Bryant Park Grill & Cafe  26900000.0   62
# 8      9                                    Balthazar  24547800.0   87
# 9     10                            Smith & Wollensky  24501000.0  107
# 13    14                      Junior's (Times Square)  23640652.0   23
# 19    20                                     Buddakan  22395577.0   67
# 30    31                                Quality Meats  18678000.0  115
# 31    32                                    Del Posto  18625033.0  194
# 42    43                       Junior's (49th Street)  17834390.0   22
# 47    48                           Sparks Steak House  17519030.0  100
# 48    49                              Quality Italian  17519000.0   95
# ...

# %%
df.loc[51:,['식당','도시']]
# Out:
#                                              식당               도시
# 51                                Abe & Louie's           Boston
# 52                                Rusty Pelican            Miami
# 53               Beauty & Essex (New York City)         New York
# 54                     Grand Central Oyster Bar         New York
# 55                         Delmonico Steakhouse        Las Vegas
# 56                          Portland City Grill         Portland
# 57                     Zehnder's of Frankenmuth      Frankenmuth
# 58                               The Rustic Inn   Ft. Lauderdale
# 59             Harry Caray's Italian Steakhouse          Chicago
# 60                             Keens Steakhouse         New York
# 61                            The Lobster House         Cape May
# 62                                   China Live    San Francisco
# 63                           Prime & Provisions          Chicago
# ...

# %%
df.rename({'평균':'평균 요금'},axis=1,inplace=True)

# %%
df
# Out:
#      랭크                                   식당         판매액  평균 요금          도시  \
# 0     1             Carmine's (Times Square)  39080335.0     40    New York
# 1     2                The Boathouse Orlando  35218364.0     43    Orlando
# 2     3                     Old Ebbitt Grill  29104017.0     33  Washington
# 3     4  LAVO Italian Restaurant & Nightclub  26916180.0     90    New York
# 4     5             Bryant Park Grill & Cafe  26900000.0     62    New York
# ..  ...                                  ...         ...    ...         ...
# 95   96                 George's at the Cove  12194000.0     80    La Jolla
# 96   97                            Le Coucou  12187523.0     95    New York
# 97   98                              Mi Vida  12032014.0     38  Washington
# 98   99                               Upland  11965564.0     52    New York
# 99  100               Virgil's Real Barbecue  11391678.0     27   Las Vegas
#
#          주       서빙수
# 0     N.Y.  469803.0
# ...

# %%
df.sort_values(['평균 요금','서빙수'],ascending=False)
# Out:
#     랭크                        식당         판매액  평균 요금           도시      주  \
# 31  32                 Del Posto  18625033.0    194     New York   N.Y.
# 37  38          Prime Steakhouse  18248030.0    173    Las Vegas   Nev.
# 21  22             SW Steakhouse  21523650.0    149    Las Vegas   Nev.
# 11  12                 Prime 112  23800000.0    135  Miami Beach   Fla.
# 63  64        Prime & Provisions  15100000.0    130      Chicago   Ill.
# ..  ..                       ...         ...    ...          ...    ...
# 76  77       Junior's (Brooklyn)  13908292.0     23     New York   N.Y.
# 42  43    Junior's (49th Street)  17834390.0     22     New York   N.Y.
# 68  69          Acme Feed & Seed  14897125.0     22    Nashville  Tenn.
# 49  50  Frankenmuth Bavarian Inn  17388751.0     19  Frankenmuth  Mich.
# 57  58  Zehnder's of Frankenmuth  16063684.0     17  Frankenmuth  Mich.
#
#          서빙수
# 31   95000.0
# 37  113600.0
# 21  145700.0
# 11  206000.0
# 63  116154.0
# ..       ...
# ...

# %%
df['도시'].isin(['New York']).sum()
# Out:
# 21

# %%
cond4 = (df['도시'] == 'New York')
df.loc[cond4,'도시'].count()
# Out:
# 21

# %%
df.loc[cond4,'도시'].sum()   #문자열 그대로 더하기를 실행함
# Out:
# 'New YorkNew YorkNew YorkNew YorkNew YorkNew YorkNew YorkNew YorkNew YorkNew YorkNew YorkNew YorkNew YorkNew YorkNew YorkNew YorkNew YorkNew YorkNew YorkNew YorkNew York'

# %%
df.describe()
# Out:
#                랭크           판매액       평균 요금            서빙수
# count  100.000000  1.000000e+02  100.000000     100.000000
# mean    50.500000  1.783343e+07   69.050000  317166.660000
# std     29.011492  5.010408e+06   34.735181  192211.390011
# min      1.000000  1.139168e+07   17.000000   87070.000000
# 25%     25.750000  1.409484e+07   39.000000  189492.500000
# 50%     50.500000  1.730078e+07   65.500000  257097.000000
# 75%     75.250000  1.990392e+07   95.000000  372079.000000
# max    100.000000  3.908034e+07  194.000000  959026.000000

# %%
df2 = df.astype({'판매액':'int','서빙수':'int'})
df.dtypes
# Out:
# 랭크         int64
# 식당        object
# 판매액      float64
# 평균 요금      int64
# 도시        object
# 주         object
# 서빙수      float64
# dtype: object

# %%
df2.dtypes
# Out:
# 랭크        int64
# 식당       object
# 판매액       int32
# 평균 요금     int64
# 도시       object
# 주        object
# 서빙수       int32
# dtype: object

# %%
df2.info
# Out:
# <bound method DataFrame.info of      랭크                                   식당       판매액  평균 요금          도시  \
# 0     1             Carmine's (Times Square)  39080335     40    New York
# 1     2                The Boathouse Orlando  35218364     43    Orlando
# 2     3                     Old Ebbitt Grill  29104017     33  Washington
# 3     4  LAVO Italian Restaurant & Nightclub  26916180     90    New York
# 4     5             Bryant Park Grill & Cafe  26900000     62    New York
# ..  ...                                  ...       ...    ...         ...
# 95   96                 George's at the Cove  12194000     80    La Jolla
# 96   97                            Le Coucou  12187523     95    New York
# 97   98                              Mi Vida  12032014     38  Washington
# 98   99                               Upland  11965564     52    New York
# 99  100               Virgil's Real Barbecue  11391678     27   Las Vegas
#
#          주     서빙수
# 0     N.Y.  469803
# ...

# %%
df2.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   랭크      100 non-null    int64
#  1   식당      100 non-null    object
#  2   판매액     100 non-null    int32
#  3   평균 요금   100 non-null    int64
#  4   도시      100 non-null    object
#  5   주       100 non-null    object
#  6   서빙수     100 non-null    int32
# dtypes: int32(2), int64(2), object(3)
# memory usage: 22.3 KB

# %%
df2.isnull().sum()
# Out:
# 랭크       0
# 식당       0
# 판매액      0
# 평균 요금    0
# 도시       0
# 주        0
# 서빙수      0
# dtype: int64

# %%
df2['평균 요금'].dtype
# Out:
# dtype('int64')

# %%
df2['평균 요금'].astype('float')
df2['평균 요금'].dtype            #변경은 대입해줘야 함
# Out:
# dtype('int64')
